# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', 30)
pd.set_option('display.float_format', '{:.4f}'.format)

# %%
df_brand = pd.read_csv('../data/raw/brand_metadata.csv')
df_brand
# Out:
#      BRAND_ID                        PUBLISHER_UUID         BRAND_NAME  \
# 0        4313  b6f8dbb2-3e80-4126-8a68-fc2f8130b526        Lumen Carry
# 1        2208  b7dea133-983b-4e7b-8fac-b18d88340882  Greenfield Pantry
# 2        5124  739078ad-43e5-4f4d-aa8f-25cdb0030f2f        CardCompare
# 3        2165  da9c1172-323c-490e-b9f7-2249703c1d00           Reusabag
# 4        5427  3b2a9c7f-b856-4eaf-ad9b-d1eb0bee90a1   Northpoint Skate
# ..        ...                                   ...                ...
# 337      5240  9bef125b-ea76-4d46-a087-30720e7c5cf4        Henley 1909
# 338      5200  17ed82df-7059-4fab-befb-8b8f76e0d322              AURUM
# 339      5399  b0485362-676a-401e-9430-685728f5f8aa      FreckledPoppy
# 340      5293  0bc82e1f-13d4-4994-a35a-1403806eb096    Compass - Nifty
# 341      1881  6af970be-e473-47de-aec8-720014d33aa4               Kohi
#
#           PRIMARY_CATEGORY                                      SUBCATEGORIES  \
# ...

# %%
df_events = pd.read_csv('../data/raw/events_train.csv')
df_events
# Out:
#                                   SESSION_ID        SESSION_START_AT_UTC  \
# 0       4f45ecb3-f940-42fc-a8c6-54ca0c734f43  2026-04-16 00:18:45.144+00
# 1       b20c87f8-05c4-4103-9fec-adc2bc7af183  2026-04-16 01:12:12.026+00
# 2       af103558-69e4-4f52-a9df-9f99312b6535  2026-04-16 02:53:35.691+00
# 3       678c9848-5305-4ac1-a643-17c4873bd271  2026-04-16 02:07:17.719+00
# 4       a9a4af35-5493-4d5f-8961-ecaf7b2682ba  2026-04-16 01:56:30.462+00
# ...                                      ...                         ...
# 471671  1f69dae4-e69b-41c9-a6a3-d8f4e110c95a  2026-03-10 13:54:37.243+00
# 471672  59e5b0ab-9c43-4d9b-973e-7dd267ca2658  2026-03-10 23:59:54.357+00
# 471673  7add2ff3-e435-498b-a3b8-183a55bd02a3  2026-03-10 19:35:05.591+00
# 471674  be12997c-a0db-405c-9c9e-a9f3466edc9a  2026-04-15 17:14:33.893+00
# 471675  917cce7f-9765-4da7-80de-eba0d8cbb14a  2026-04-15 00:33:45.878+00
#
#                                IDENTITY_UUID        PUBLISHER_NAME  \
# ...

# %%
df_events['WIDGET_TYPE'].value_counts(dropna=False)
# Out:
# WIDGET_TYPE
# APP_NATIVE_ESSENTIAL        388937
# SHOPIFY_NATIVE_ESSENTIAL     54855
# ESSENTIAL                    25816
# SHOPIFY_NATIVE_LEAD_GEN       1157
# APP_NATIVE_BRAND_VISUAL        892
# LEAD_GEN                        19
# Name: count, dtype: int64

# %%
df_events['WIDGET_VERSION'].value_counts(dropna=False)
# Out:
# WIDGET_VERSION
# 0.2000    426064
# 0.1000     34479
# 0.3000      9957
# 0.5100      1157
# 0.5500        19
# Name: count, dtype: int64

# %%
df_events['OS_CLASS'].value_counts(dropna=False)
# Out:
# OS_CLASS
# Mobile     398990
# Desktop     55936
# Unknown     16632
# Cloud         105
# Hacker         13
# Name: count, dtype: int64
